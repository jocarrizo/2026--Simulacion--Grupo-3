# %% [markdown]
# # Procesamiento y ajuste de datos mediante el uso de Python y Google Colab
#
# El objetivo de este trabajo consiste en:
#
# 1.   Realizar el procesamiento de un set de datos de transporte mediante el uso del lenguaje programación Python y las bibliotecas Pandas y Numpy, utilizando el entorno de Google Colab.
# 2.   Obetener información necesaria del dataset con Pandas y desarrollar visualizaciones básicas de los datos mediante la librería MatPlotlib.
# 3.   Ajustar los datos de origen a una serie de funciones de densidad de probabilidad sugeridas, mediante el uso de la biblioteca Fitter.
# 4.   Con la obtención de la(s) fdp(s) sugeridas, simular un array de datos y verificar por medio de gráficos o un nuevo ajuste, que los datos generados son de características similares a los de orígen.
#
# Este análisis lo realizaremos mediante el entorno de Google Colab. Pueden investigar más sobre este entorno y sus funcionalidades en el siguiente link:
#
# https://colab.research.google.com/
#
# Como se puede observar, este mismo documento es un cuaderno (o también llamado Notebook) de Google Colab.
#
# Las notebooks tienen dos tipos de celdas:
# 1. **Código**: En dónde podemos introducir código Python, ejecutarlo y ver el resultado.
# 2. **Texto**: Podemos incluir como un documento, código HTML, LaTex, imágenes y demás.
#
#
# **Importante**: Para replicar el análisis de este notebook, deberán realizarse una copia del mismo (Menú: Archivo -> Guardar una copia en Drive).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Importación de bibliotecas
#
# En este primer paso importamos todas las bibliotecas necesarias para realizar nuestro procesamiento de datos. Numpy y Pandas para el manejo de datos y Matplotlib para gráficos.
#
# Generalmente es buena práctica utilizar alias para los nombres de estas bibliotecas (np, pd y plt) cuando se las importa.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## 2. Carga de datos
#
# Debido a que nuestro dataset a procesar es un archivo excel, utilizaremos la función *read_excel* de la biblioteca Pandas.
#
# Los detalles del uso de esta función se encuentran en el siguiente link:
# [pandas.read_excel](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html)
#
# En este código de ejemplo, el archivo a leer se encuentra en una carpeta de Google Drive propia, que previamente hay que "montar" mediante el menú de la izquierda.
# En los parámetros que le pasamos a read_excel debemos poner el link de nuestra ubicación del archivo que nos guardamos en nuestro drive.
#
# Los datos leídos los cargamos en una variable que llamamos *transporte_datos*.
#
# Observese que mediante el parámetro sheet_name le indicamos que hoja del excel vamos a cargar.
#
# Se puede bajar y cargar el dataset (FINAL_HORAS_NOVIEMBRE_Nacional_DF.xlsx) del siguiente [link](https://docs.google.com/spreadsheets/d/18CtL-RQgNgEHLrjOKtlGOwPpfM6FgEt_/edit?usp=sharing&ouid=103939068473979530439&rtpof=true&sd=true).

# %%
# Atención: modificar la ubicación del archivo en donde lo tengan en su propio drive
transporte_datos = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Simulacion/Datos/FINAL_HORAS_NOVIEMBRE_Nacional_DF.xlsx", sheet_name='Datos')

# %% [markdown]
# Con la instrucción *type* podemos ver que esta última varible se trata de un *DataFrame* de Pandas.

# %%
type(transporte_datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos pensar a un DataFrame como una típica tabla que alguna vez utilizamos en un motor de bases de datos o simplemente en Excel.

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Análisis exploratorio de datos

# %% [markdown]
# ### Dimensionalidad

# %% [markdown]
# Lo primero que podemos realizar con nuestro DataFrame es ver su "dimensionalidad" (Cantidad de filas por columnas).
# Para ello utilizamos el atributo [*shape*](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html) de Pandas.

# %%
transporte_datos.shape
# Out:
# (43422, 10)

# %% [markdown]
# Podemos ver el contenido de los primeros registros del DataFrame mediante la función  [*head()*](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)
#
# Podemos pasar como parámetro la cantidad de primeros x registros a ver. En el siguiente ejemplo, los 10 primeros:

# %%
transporte_datos.head(10)
# Out:
#   AMBA GRUPO         DIA                                  EMPRESA      LINEA  \
# 0   SI    DF  13/11/2023    D.O.T.A. S.A. DE TRANSPORTE AUTOMOTOR   LINEA 44
# 1   SI    DF  16/11/2023           NUEVOS RUMBOS S.A.T.A.C.I.F.I.  LINEA 132
# 2   SI    DF  17/11/2023                 COLECTIVEROS UNIDOS S.A.  LINEA_099
# 3   SI    DF  19/11/2023    LINEA DE MICROOMNIBUS 47 S.A.T.C.F.I.   LINEA 47
# 4   SI    DF  10/11/2023    M.O.D.O. S.A. DE TRANSPORTE AUTOMOTOR  LINEA 151
# 5   SI    DF  19/11/2023    M.O.D.O. S.A. DE TRANSPORTE AUTOMOTOR   LINEA 90
# 6   SI    DF  08/11/2023                 COLECTIVEROS UNIDOS S.A.  LINEA_099
# 7   SI    DF  11/11/2023  MICROOMNIBUS BARRANCAS DE BELGRANO S.A.  LINEA 118
# 8   SI    DF  10/11/2023    LINEA DE MICROOMNIBUS 47 S.A.T.C.F.I.   LINEA 47
# 9   SI    DF  23/11/2023         TRANSPORTES SOL DE MAYO C.I.S.A.    LINEA 4
#
#    INTERNO  HORAS  SUMA_KM  SUMA_MINUTOS JURISDICCION
# 0        4   0.00     0.19             0     NACIONAL
# 1      108   0.00     0.07             0     NACIONAL
# 2     4546   0.00     0.05             0     NACIONAL
# 3      107   0.00     0.04             0     NACIONAL
# 4      419   0.02     0.33             1     NACIONAL
# 5      468   0.02     0.07             1     NACIONAL
# 6     4569   0.02     0.49             1     NACIONAL
# 7       36   0.02     0.06             1     NACIONAL
# 8      143   0.03     2.12             2     NACIONAL
# 9        4   0.03     0.27             2     NACIONAL

# %% [markdown]
# ### Tipos de datos
# Oberservamos los tipos de datos de cada una de las columnas con el atributo [*dtypes*](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html).

# %%
transporte_datos.dtypes
# Out:
# AMBA             object
# GRUPO            object
# DIA              object
# EMPRESA          object
# LINEA            object
# INTERNO           int64
# HORAS           float64
# SUMA_KM         float64
# SUMA_MINUTOS      int64
# JURISDICCION     object
# dtype: object

# %% [markdown]
# Para este trabajo, nos interesa la columna "HORAS" y vemos que la misma es de tipo float.
#
# Si la columna que queremos trabajar fuese de tipo "object" deberíamos previamente converirlo a tipo integer o floar mediante la función [*astype*](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html).

# %% [markdown]
# ### Inspección de datos nulos
#
# Una forma de verificar si el DataFrame contiene datos nulos es mediante la función isnull(). Si agregarmos sum() obtenemos el total de nulos por columnas.
# En nuestro dataset observamos que no tenemos datos nulos.

# %%
transporte_datos.isnull().sum()
# Out:
# AMBA            0
# GRUPO           0
# DIA             0
# EMPRESA         0
# LINEA           0
# INTERNO         0
# HORAS           0
# SUMA_KM         0
# SUMA_MINUTOS    0
# JURISDICCION    0
# dtype: int64

# %% [markdown]
# ### Acceso a datos
#
# Para acceder a los datos de una columna específica de un DataFrame podemos utilizar el operador punto (.), es decir ponemos el nombre del DF, más un . y el nombre de la columna. De esta manera:

# %%
transporte_datos.HORAS
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.02
#          ...
# 43417    23.98
# 43418    23.98
# 43419    23.98
# 43420    23.98
# 43421    24.00
# Name: HORAS, Length: 43422, dtype: float64

# %% [markdown]
# Esto último lo podemos hacer si el nombre de la columna no tiene espacios en su nombre. Si fuese así, podemos acceder a los datos de la columna mediante el uso de corchetes []., De esta manera:

# %%
transporte_datos['HORAS']
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.02
#          ...
# 43417    23.98
# 43418    23.98
# 43419    23.98
# 43420    23.98
# 43421    24.00
# Name: HORAS, Length: 43422, dtype: float64

# %% [markdown]
# ## 4. Visualización de Datos

# %% [markdown]
# Es buena práctica recurrir a una visualización para obtener un panorama de la distribución de nuestros datos.
#
# Recurrimos a la biblioteca [Matplotlib](https://matplotlib.org/) para graficar un histograma o gráfico de frecuencia.
#
# Para construir este gráfico utilizamos la función hist de Matplotlib y pasamos como parámetros la columna con los valores que queremos contar (HORAS) y la cantidad de rangos o bins que consideramos para nuestros datos. En este ejemplo tomamos 200.

# %%
# Histograma de HORAS
plt.title("Histograma")
plt.xlabel("Horas")
plt.ylabel("Frecuencia")
plt.hist(transporte_datos.HORAS, bins=200)
plt.show()

# %% [markdown]
# ## 5. Ajuste de Datos

# %% [markdown]
# Para poder ajustar nuestros datos a una fdp conocida es necesario que previamente instalemos en nuestro entorno Colab el paquete de la [biblioteca Fitter](https://fitter.readthedocs.io/en/latest/).
#
# La instalación se realiza fácilmente mediante la instrucción [*pip install*](https://pip.pypa.io/en/stable/cli/pip_install/).
#
# Una vez instalado el paquete, se nos pedirá reiniciar el entorno de Colab.

# %%
pip install fitter
# Out:
# Requirement already satisfied: fitter in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from fitter) (8.1.7)
# Requirement already satisfied: joblib<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.3.2)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (0.7.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (3.8.4)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.25.2)
# Requirement already satisfied: pandas<3.0.0,>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from fitter) (2.0.3)
# Requirement already satisfied: rich-click<2.0.0,>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.7.4)
# Requirement already satisfied: scipy<2.0.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.11.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (24.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.1)
# Requirement already satisfied: rich>=10.7.0 in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (13.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (4.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.2->fitter) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7.0->rich-click<2.0.0,>=1.7.2->fitter) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7.0->rich-click<2.0.0,>=1.7.2->fitter) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7.0->rich-click<2.0.0,>=1.7.2->fitter) (0.1.2)

# %% [markdown]
# Ahora si podemos importar la [librería Fitter](https://fitter.readthedocs.io/en/latest/#what-is-it) propiamente.

# %%
#Importamos fitter
from fitter import Fitter

# %% [markdown]
# Cargamos los datos de la columna de nuestro DataFrame que queremos ajustar en una variable que llamamos "f".

# %%
f = Fitter(transporte_datos.HORAS)

# %% [markdown]
# **La** función fit() de Fitter ajusta los datos recorriendo más de 80 distribuciones disponibles de la biblioteca scipy que previamente importamos. Podríamos indicarle en forma de lista, distribuciones con las cuales queremos que realice la prueba de ajuste, si es que conocemos de antemano que nuestros datos ajustará a alguna de ellas. Por ejemplo así:
#
# `fit(datos, distributions=['gamma','rayleigh','uniform'])`
#
# Tener en cuenta que si no pasamos ningún parámetro, la función fit() escaneará las 80 funciones de scipy y demorará varios minutos en el proceso.

# %%
f.fit()
# Out:
# 2024-04-08 01:13:39.740 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED _fit distribution (taking more than 30 seconds)
# 2024-04-08 01:13:44.489 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted anglit distribution with error=0.138066)
# 2024-04-08 01:13:45.993 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted arcsine distribution with error=0.296196)
# 2024-04-08 01:13:47.275 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted alpha distribution with error=0.081928)
# 2024-04-08 01:13:57.434 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=0.381642)
# 2024-04-08 01:13:58.760 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted argus distribution with error=0.136815)
# 2024-04-08 01:14:00.306 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted bradford distribution with error=0.210532)
# 2024-04-08 01:14:13.432 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted betaprime distribution with error=0.072526)
# 2024-04-08 01:14:30.351 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED burr distribution (taking more than 30 seconds)
# 2024-04-08 01:14:31.659 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.0112)
# 2024-04-08 01:14:40.078 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi distribution with error=0.07281)
# 2024-04-08 01:14:40.716 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr12 distribution with error=0.067221)
# 2024-04-08 01:14:45.472 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cosine distribution with error=0.109104)
# 2024-04-08 01:14:51.516 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.082413)
# 2024-04-08 01:14:58.585 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted crystalball distribution with error=0.07028)
# 2024-04-08 01:15:01.538 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dgamma distribution with error=0.017782)
# 2024-04-08 01:15:05.902 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dweibull distribution with error=0.017476)
# 2024-04-08 01:15:05.964 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.295472)
# 2024-04-08 01:15:08.047 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted erlang distribution with error=0.079296)
# 2024-04-08 01:15:10.309 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponnorm distribution with error=0.07028)
# 2024-04-08 01:15:31.995 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=1.051316)
# 2024-04-08 01:15:40.353 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED exponweib distribution (taking more than 30 seconds)
# 2024-04-08 01:15:57.494 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted f distribution with error=0.873343)
# 2024-04-08 01:15:57.980 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fatiguelife distribution with error=0.070265)
# 2024-04-08 01:16:00.180 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldcauchy distribution with error=0.158705)
# 2024-04-08 01:16:14.368 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldnorm distribution with error=0.070723)
# 2024-04-08 01:16:25.904 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.07826)
# 2024-04-08 01:16:27.513 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED fisk distribution (taking more than 30 seconds)
# 2024-04-08 01:16:55.953 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gausshyper distribution (taking more than 30 seconds)
# 2024-04-08 01:16:57.126 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genexpon distribution with error=0.186333)
# 2024-04-08 01:17:26.007 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED genextreme distribution (taking more than 30 seconds)
# 2024-04-08 01:17:27.156 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gengamma distribution (taking more than 30 seconds)
# 2024-04-08 01:17:46.316 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhalflogistic distribution with error=0.166098)
# 2024-04-08 01:17:57.221 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# 2024-04-08 01:18:00.478 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genlogistic distribution with error=0.022638)
# 2024-04-08 01:18:12.202 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gennorm distribution with error=0.016289)
# 2024-04-08 01:18:16.374 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED geninvgauss distribution (taking more than 30 seconds)
# 2024-04-08 01:18:26.828 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gibrat distribution with error=0.252812)
# 2024-04-08 01:18:27.686 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genpareto distribution with error=0.946937)
# 2024-04-08 01:18:28.143 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_l distribution with error=0.050981)
# 2024-04-08 01:18:28.581 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_r distribution with error=0.131224)
# 2024-04-08 01:18:40.245 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gompertz distribution with error=0.053017)
# 2024-04-08 01:18:40.403 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfcauchy distribution with error=0.277705)
# 2024-04-08 01:18:49.502 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halflogistic distribution with error=0.259955)
# 2024-04-08 01:18:52.694 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfnorm distribution with error=0.254223)
# 2024-04-08 01:18:53.964 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted hypsecant distribution with error=0.035147)
# 2024-04-08 01:19:04.603 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfgennorm distribution with error=0.19476)
# 2024-04-08 01:19:08.264 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgamma distribution with error=0.082092)
# 2024-04-08 01:19:19.536 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgauss distribution with error=0.105926)
# 2024-04-08 01:19:38.309 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED invweibull distribution (taking more than 30 seconds)
# 2024-04-08 01:19:47.761 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsu distribution with error=0.010913)
# 2024-04-08 01:19:49.611 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED johnsonsb distribution (taking more than 30 seconds)
# 2024-04-08 01:20:17.830 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kappa3 distribution (taking more than 30 seconds)
# 2024-04-08 01:20:19.672 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kappa4 distribution (taking more than 30 seconds)
# 2024-04-08 01:20:19.814 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kstwo distribution (taking more than 30 seconds)
# 2024-04-08 01:20:29.377 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kstwobign distribution with error=0.15118)
# 2024-04-08 01:20:29.612 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace distribution with error=0.01832)
# 2024-04-08 01:20:32.818 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace_asymmetric distribution with error=0.009795)
# 2024-04-08 01:20:36.077 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ksone distribution with error=0.212854)
# 2024-04-08 01:20:37.327 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy distribution with error=0.289797)
# 2024-04-08 01:20:38.982 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_l distribution with error=0.251125)
# 2024-04-08 01:20:40.371 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loggamma distribution with error=0.047766)
# 2024-04-08 01:20:40.782 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted logistic distribution with error=0.047341)
# 2024-04-08 01:21:01.775 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loglaplace distribution with error=0.01828)
# 2024-04-08 01:21:07.387 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED levy_stable distribution (taking more than 30 seconds)
# 2024-04-08 01:21:13.365 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loguniform distribution with error=1.510693)
# 2024-04-08 01:21:18.856 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lomax distribution with error=0.438168)
# 2024-04-08 01:21:20.160 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted maxwell distribution with error=0.134372)
# 2024-04-08 01:21:25.198 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.071391)
# 2024-04-08 01:21:28.680 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted moyal distribution with error=0.154959)
# 2024-04-08 01:21:37.083 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nakagami distribution with error=0.070541)
# 2024-04-08 01:21:49.421 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted mielke distribution with error=0.101909)
# 2024-04-08 01:22:07.105 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED ncf distribution (taking more than 30 seconds)
# 2024-04-08 01:22:19.469 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED nct distribution (taking more than 30 seconds)
# 2024-04-08 01:22:19.556 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.07028)
# 2024-04-08 01:22:37.185 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED ncx2 distribution (taking more than 30 seconds)
# 2024-04-08 01:22:38.192 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pareto distribution with error=0.295472)
# 2024-04-08 01:22:54.783 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pearson3 distribution with error=0.052879)
# 2024-04-08 01:22:55.105 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.188921)
# 2024-04-08 01:23:25.254 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED powerlognorm distribution (taking more than 30 seconds)
# 2024-04-08 01:23:43.019 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powernorm distribution with error=0.0472)
# 2024-04-08 01:23:43.764 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.1702)
# 2024-04-08 01:24:03.149 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rdist distribution with error=0.070632)
# 2024-04-08 01:24:33.191 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# 2024-04-08 01:24:41.367 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted reciprocal distribution with error=1.510693)
# 2024-04-08 01:24:55.568 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rel_breitwigner distribution with error=0.00473)
# 2024-04-08 01:25:25.588 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rice distribution (taking more than 30 seconds)
# 2024-04-08 01:25:25.630 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_continuous distribution (taking more than 30 seconds)
# 2024-04-08 01:25:25.709 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_histogram distribution (taking more than 30 seconds)
# 2024-04-08 01:25:30.040 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted semicircular distribution with error=0.16443)
# 2024-04-08 01:25:35.311 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewcauchy distribution with error=0.008598)
# 2024-04-08 01:25:45.543 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewnorm distribution with error=0.047136)
# 2024-04-08 01:26:08.871 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norminvgauss distribution with error=0.010492)
# 2024-04-08 01:26:15.679 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED studentized_range distribution (taking more than 30 seconds)
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_quadpack_py.py:1233: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# 2024-04-08 01:26:22.592 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapezoid distribution with error=0.201842)
# 2024-04-08 01:26:29.854 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapz distribution with error=0.201842)
# 2024-04-08 01:26:39.029 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED t distribution (taking more than 30 seconds)
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_quadpack_py.py:1233: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# 2024-04-08 01:26:42.325 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncexpon distribution with error=0.233339)
# 2024-04-08 01:26:43.675 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted triang distribution with error=0.084406)
# 2024-04-08 01:26:56.636 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncnorm distribution with error=0.223175)
# 2024-04-08 01:26:57.426 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncpareto distribution with error=0.315035)
# 2024-04-08 01:27:26.683 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# 2024-04-08 01:27:26.821 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.208031)
# 2024-04-08 01:27:27.092 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises distribution with error=1.730232)
# 2024-04-08 01:27:27.126 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_fisher distribution (taking more than 30 seconds)
# 2024-04-08 01:27:27.474 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED tukeylambda distribution (taking more than 30 seconds)
# 2024-04-08 01:27:33.799 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wald distribution with error=0.244143)
# 2024-04-08 01:27:45.280 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises_line distribution with error=0.241884)
# 2024-04-08 01:27:45.672 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_max distribution with error=1.261702)
# 2024-04-08 01:27:51.142 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wrapcauchy distribution with error=0.208031)
# 2024-04-08 01:27:51.823 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_min distribution with error=0.049424)

# %% [markdown]
# La función sumary():
#
# `summary(Nbest=5, lw=2, plot=True, method='sumsquare_error', clf=True)`
#
# grafica la distribución de las N mejores distribuciones.

# %%
f.summary(10)
# Out:
#                     sumsquare_error         aic         bic    kl_div  \
# rel_breitwigner            0.004730  750.982059  777.018223  0.023131
# skewcauchy                 0.008598  802.509844  828.546008  0.029611
# laplace_asymmetric         0.009795  775.015271  801.051436  0.030226
# norminvgauss               0.010492  788.727538  823.442424  0.035661
# johnsonsu                  0.010913  790.701160  825.416046  0.035979
# cauchy                     0.011200  811.194603  828.552046  0.044686
# gennorm                    0.016289  787.669459  813.705624  0.050965
# dweibull                   0.017476  786.399838  812.436003  0.052735
# dgamma                     0.017782  789.789898  815.826062  0.053925
# loglaplace                 0.018280  787.945119  813.981284  0.055383
#
#                     ks_statistic      ks_pvalue
# rel_breitwigner         0.024624   2.639827e-23
# skewcauchy              0.061437  6.359632e-143
# laplace_asymmetric      0.030433   2.259675e-35
# norminvgauss            0.036244   5.385677e-50
# johnsonsu               0.033778   1.768122e-43
# cauchy                  0.067119  1.605374e-170
# gennorm                 0.064893  2.027708e-159
# dweibull                0.067481  2.289882e-172
# dgamma                  0.065763  1.032919e-163
# loglaplace              0.065149  1.125902e-160

# %% [markdown]
# Fitter me devuelve las mejores distribuciones de ajuste de acuerdo a distintos criterios *(sumsquare_error, aic,	bic, kl_div, ks_statistic,ks_pvalue)*.
# Podemos por ejemplo obtener la mejor distribución, considerando el criterio de la [suma residual de cuadrados](https://es.wikipedia.org/wiki/Suma_residual_de_cuadrados).

# %%
# Obtengo los parámetros de la mejor fdp
f.get_best(method='sumsquare_error')
# Out:
# {'rel_breitwigner': {'rho': 4.041298404882269,
#   'loc': -0.0011996563210242908,
#   'scale': 3.755282486437009}}

# %% [markdown]
# En este último ejemplo nos devuelve que la mejor distribución es la ["Breit-Wigner relativista"](https://es.wikipedia.org/wiki/Distribuci%C3%B3n_de_Breit-Wigner_relativista).
#
# No está demás que con cada distribución sugerida, consultemos la [documentación de la misma en Scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.rel_breitwigner.html).
#
# La función de densidad de probabilidad de Breit-Wigner relativista es:
#
# $\begin{equation}f(x,\rho) = \frac{k}{(x^2 - \rho^2)^2 + \rho^2}
# \end{equation}$
#
#
#
# En donde $k$ es:
#
# $\begin{equation}k = \frac{2\sqrt 2 \rho^2 \sqrt{\rho^2+1}}{\pi\sqrt{\rho^2 + \rho\sqrt{\rho^2+1}}}
# \end{equation}$
#
# Los 3 parámetros devueltos (*rho, loc* y *scale*) corresponden **propriamente a esta función de distribución** y será de utilidad la hora de generar valores
# aleatorios. Investigar en la documentación de Scipy los parámetros específicos de cada distribución con la que elijamos trabajar.

# %% [markdown]
# ## 6. Verificación

# %% [markdown]
# Los valores de los parámetros que nos había devuelto *get_best()* para la distribución Breit-Wigner, los cargamos en 3 variables:

# %%
rho = 4.041298404882269
loc = -0.0011996563210242908
scale =  3.755282486437009

# %% [markdown]
# La idea es que mediante la [biblioteca de funciones estadística scipy.stats](https://docs.scipy.org/doc/scipy/reference/stats.html) generamos un array de datos con esta distribución:

# %%
f_verif = stats.rel_breitwigner.rvs(rho, loc, scale, size=4000, random_state=None)

# %% [markdown]
# Como mencionamos, el tipo de dato de esta variable creada es un array de numpy.

# %%
type(f_verif)
# Out:
# numpy.ndarray

# %% [markdown]
# En el parámetro size le indicamos que el tamaño de este array es de 4000.
#
# De esta manera, pudimos "simular" un set de datos similar a los datos de origen con los cuales inciamos nuestro análisis.

# %%
f_verif
# Out:
# array([12.24555495, 14.94884352, 19.14712037, ..., 20.89608837,
#        11.1861197 , 12.52038086])

# %% [markdown]
# Una primera forma de verificar nuestro análisis es realizando un histograma con los datos generados:

# %%
# Histograma de datos de verificación
plt.title("Histograma")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.xlim(0, 30)
plt.ylim(0, 5000)
plt.hist(f_verif, bins=200)
plt.show()

# %% [markdown]
# ### Opcional
#
# De la misma manera, si realizamos un buen análisis, aplicando los datos de verificación a Fitter debería ajustar a la función previamente sugerida:

# %%
v = Fitter(f_verif, distributions=['uniform', 'rel_breitwigner','skewcauchy','norminvgauss'])

# %%
v.fit()
# Out:
# 2024-04-08 03:51:27.525 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.052388)
# 2024-04-08 03:51:29.927 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewcauchy distribution with error=0.000409)
# 2024-04-08 03:51:32.050 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rel_breitwigner distribution with error=0.005509)
# 2024-04-08 03:51:59.970 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED norminvgauss distribution (taking more than 30 seconds)

# %%
v.summary(6)
# Out:
# 2024-04-08 03:52:12.518 | WARNING  | fitter.fitter:plot_pdf:417 - norminvgauss was not fitted. no parameters available
#                  sumsquare_error          aic          bic  kl_div  \
# skewcauchy              0.000409  1710.045206  1735.835111     inf
# rel_breitwigner         0.005509  1903.010356  1928.800260     inf
# uniform                 0.052388  1016.514751  1033.708020     inf
# norminvgauss                 inf          inf          inf     inf
#
#                  ks_statistic     ks_pvalue
# skewcauchy           0.052454  4.316288e-96
# rel_breitwigner      0.114003  0.000000e+00
# uniform              0.825103  0.000000e+00
# norminvgauss              NaN           NaN

# %% [markdown]
# ## 7. Conclusión
#
# Observando el array de datos generados con la función de *stats.rel_breitwigner* y posteriormente observando su distribución en el histograma podemos concluir sobre la similitud con los datos de origen.
#
# Para ser mucho más exhaustivo podemos con este array simulado volver a ajustar los datos con Fitter como hicimos en la última parte del inciso 6, y entre la lista de funciones sugeridas por Fitter, vemos que nuevamente se encuentra la función *stats.rel_breitwigner*.
