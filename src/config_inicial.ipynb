# %% [markdown]
# ### Configuración de Librerías
#
# Este bloque de código realiza la instalación de las librerías necesarias para ejecutar la simulación.

# %%
import subprocess
subprocess.run(['pip', 'install', 'fitter numpy pandas scipy matplotlib', '--quiet'], check=True)
# %pip install numpy pandas scipy matplotlib fitter
